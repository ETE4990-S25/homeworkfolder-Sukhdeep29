# %% [markdown]
# # Lab 2 - Refactoring
# ## Refactoring is:
#
# Refactoring is the process of restructuring or rewriting code, while not changing its original functionality. The goal of refactoring is to improve internal code by making many small changes without altering the code's external behavior.
#
# It is easier said than done.

# %% [markdown]
# ### Part 1 - Warm-up
#
# You will refactor the following code:

# %%
#stolen from https://realpython.com/python-refactoring/
#yes you can go there and look at what they did no do it yourself
x = 5
value = input("Enter a number: ")
y = int(value)
if x < y:
    print(f"{x} is less than {y}")
elif x == y:
    print(f"{x} is equal to {y}")
else:
    print(f"{x} is more than {y}")
# Out:
# Enter a number:  1
# 5 is more than 1

# %%
# put your refactored code here
#Sukhdeep Kaur January 31, 2025
solution = 5
yourGuess = int(input("Enter a number:"))
if solution < yourGuess:
    print("less than")
elif solution == yourGuess:
    print("equal to")
else:
    print("more than")

print(f"{yourGuess}")

# %% [markdown]
# ## Part 2
# Refactor the following

# %%
def a(x, y):
    if x == "wizard":
        if y == "fireball":
            return "casts fireball"
        elif y == "lightning":
            return "casts lightning"
        else:
            return "does nothing"
    elif x == "warrior":
        if y == "slash":
            return "slashes with sword"
        elif y == "bash":
            return "bashes with shield"
        else:
            return "does nothing"
    else:
        return "does nothing"

def b(z):
    for i in range(10):
        if z == "dragon":
            return "fights dragon"
        elif z == "goblin":
            return "fights goblin"
        elif z == "orc":
            return "fights orc"
        else:
            return "does nothing"

def c():
    for i in range(5):
        print("exploring dungeon")
    for j in range(5):
        print("finding treasure")

def main():
    print(a("wizard", "fireball"))
    print(a("warrior", "slash"))
    print(b("dragon"))
    c()

# %%
# put your refactored code here
# Sukhdeep Kaur January 31, 2025
def action(character, power):
    if character == "wizard":
        if power == "fireball":
            return "Wizard casts Fireball!"
        elif power == "lightning":
            return "Wizard casts Lightning!"
    elif character == "warrior":
        if power == "slash":
            return "Warrior slashes with sword!"
        elif power == "bash":
            return "Warrior bashes with shield!"
    else:
         return "Does nothing"
    

def animal(ability):
    for ability in range(10):
        if ability == "dragon":
            return "fights dragon"
        elif ability == "goblin":
            return "fights goblin"
        elif ability == "orc":
            return "fights orc"
        else:
            return "does nothing"
    
def game():
    for i in range(5):
        print("exploring dungeon")
    for j in range(5):
        print("finding treasure")


    print(action("wizard", "fireball"))
    print(animal("warrior", "slash"))
    print(game("dragon"))
    game()

# %% [markdown]
# # Part 3
# Refactor your partners lab 1 code so it is a clean function. Look at part 4 and see how you can adapt the code to fit project one.

# %%
#My partner's Lab without refactoring


# ## Mini-Project - Dice Roll
# 
# Part 1:
# Create a random number generator using dice. 
# You must create at least 5 dice
# The game must use conditionals (If, Else, Elif)
# The game must use nested conditionals (if 0=0:if 1=1: do something)
# 
# What lists should we create for the project?
# How many loops do we need?
# 
# Part 2:
# Create a list to store your gameplay. 
# Create at least 2 lists to store your game statistics.
# 
# Part 3:
# At the end of the output your gameplay statistics
# 
# Part 4:
# Exchange code with your partner and begin adding comments on improvements (save your original version)
# 
# Part 5:
# Return the code and create a comparison 
# 
# Part 6:
# Upload the code and comparison it to Canvas. 

# In[102]:


import random


# In[144]:


#Joanna Escobar 1/24/2025

#title and instructions
print("Random Number Generator")
print("Welcome! You have chosen to play a dice game! I will roll 5 dice, and you will guess the total!")
print("If you get within one number of the total, you win! If not, I win!")
print()
print("Guess a number between 6 and 30!")

counter = 0
#Lists
User_Guesses = []
User_Wins = []
Computer_Wins = []

#for loop structure taken from GeeksforGeeks. The internal contents are my own. 
for counter in range(0,5):
    #dice roll
    dice_1 = random.randint(1,6) 
    dice_2 = random.randint(1,6)
    dice_3 = random.randint(1,6)
    dice_4 = random.randint(1,6)
    dice_5 = random.randint(1,6)
    #add dice roll
    dice_Total = dice_1+dice_2+dice_3+dice_4+dice_5
    
    #checking dice
    #print(dice_1," ",dice_2," ",dice_3," ",dice_4," ",dice_5," ", "Total:",dice_Total)
    
    #Inputting information
    print("Please enter your guess... ")
    user_Input = int(input())
    
    #Checking the Results/Playing the Game
    if user_Input > 30 or user_Input < 5:
        print("Whoops! Not in range! Please guess again.")
        print("Please enter your guess... ")
        user_Input = int(input())
    elif user_Input == dice_Total:
        print("Exactly right! You won! Well done!")
        
        User_Wins.append(1)
        Computer_Wins.append(0)
    else:
        one_Positive = user_Input +1
        one_Negative = user_Input -1
        if one_Positive == dice_Total or one_Negative == dice_Total:
            print("You won! Off by one!")
            
            User_Wins.append(1)
            Computer_Wins.append(0)
        else:
            print("Not quite. I won!")
            
            User_Wins.append(0)
            Computer_Wins.append(1)

    print("Your guess: ", user_Input) 
    print("Dice Total: ", dice_Total)
    
    #Guess list iteration
    User_Guesses.append(user_Input)
    
    
    counter = counter +1


# In[146]:


#Scoreboard
print("Scoreboard: ")
print("Your Guesses: ", User_Guesses)
print("Your Wins (by round): ", User_Wins)
print("My Wins (by round): ", Computer_Wins) ###SK: Overall, I didn't find any flaws in your code. It was a fun game where the user gets to play two games. I would just say that may be you can create a new notebook before writing a new code.

# %%
#My Attempt at my partner's lab refactoring
import random
print("Welcome to the dice roll game")
print("If you get within one number of the total, you win! If not, I win!\n")
counter=0
User_Guesses = []
User_Wins = []
Computer_Wins = []
for counter in range (0,5):
    dice_rolls= [random.randint(1,6) for i in range(5)]
    dice_total= sum(dice_rolls)
    user_input=int(input("Enter your guess from 5-30"))
    if 5>user_input<30:
        print("Whoops! Not in range! Please guess again.")
        user_input = int(input("Enter your guess from 5-30"))
    elif user_input == dice_total:
        print("Exactly right! You won! Well done!")
        
        User_Wins.append(1)
        Computer_Wins.append(0)
    else:
        one_Positive = user_input +1
        one_Negative = user_input -1
        if one_Positive == dice_total or one_Negative == dice_total:
            print("You won! Off by one!")
            
            User_Wins.append(1)
            Computer_Wins.append(0)
        else:
            print("Not quite. I won!")
            
            User_Wins.append(0)
            Computer_Wins.append(1)
    print("Your Guess:", user_input)
    print("Dice Total=", dice_total)
    User_Guesses.append(user_input)
    counter = counter +1
print("Scoreboard: ")
print("Your Guesses: ", User_Guesses)
print("Your Wins (by round): ", User_Wins)
print("My Wins (by round): ", Computer_Wins)
# Out:
# Welcome to the dice roll game
# If you get within one number of the total, you win! If not, I win!
#
# Not quite. I won!
# Your Guess: 12
# Dice Total= 15
# Not quite. I won!
# Your Guess: 32
# Dice Total= 25
# Not quite. I won!
# Your Guess: 32
# Dice Total= 13
# Not quite. I won!
# Your Guess: 45
# Dice Total= 21
# Not quite. I won!
# Your Guess: 23
# Dice Total= 16
# Scoreboard:
# Your Guesses:  [12, 32, 32, 45, 23]
# Your Wins (by round):  [0, 0, 0, 0, 0]
# My Wins (by round):  [1, 1, 1, 1, 1]

# %% [markdown]
# ## Part 4 - take home but start in class
# # Project #1  introduction
#
#
# Your task is to develop a text-based video game focusing on the player profile, inventory system, and combat mechanics. Create a realistic player character with at least 10 inventory items, each with a description and an associated trait. Enjoy the process!
#
# Incorporate all the concepts we've covered so far, including files (read and write), JSON, operators, lists, optional tuples, functions, modules, and classes.
#
# ### Requirements:
# - **Player Type Selection**: Allow players to choose their character type. Set attributes based on the choice (e.g., wizard: magic = 10, knight: magic = 0).
# - **Inventory Display**: Implement a function to show the player's inventory.
# - **Item Details**: Write a function to provide detailed information about an inventory item (e.g., Knife: "forged in the depths of Polymar", +5 magic, edged weapon, one-handed).
#   - Bonus: Calculate bonuses when equipping and unequipping items.
# - **Inventory Management**: Create functions to add and remove items from the inventory.
# - **Persistence**: Ensure the game can save and reload the player's character using files.
#
# Focus on building the player and inventory system for your text-based adventure game (similar to Zork). The map and gameplay can be developed later.
#
# ### Game Features:
# - **Player Profile**: Include player stats.
# - **Inventory System**: Implement a bag to hold items.
# - **Items**: Include 10 items, each with a description and trait (e.g., +5 magic).
# - **Concepts**: Utilize functions, loops, arrays, classes, and constants. You may also use files and structs if desired.
# - **Player Type Selection**: Allow players to choose their character type and set attributes accordingly (e.g., wizard: magic = 10, knight: magic = 0).
# - **Inventory Display**: Implement a function to show the player's inventory.
# - **Code Quality**: Keep your code clean and consider various player needs, as this project will be handed off to a partner for further development.

# %% [markdown]
# # Project 1 - Part 1
# Spend time planning out your code. You may work with your partner to plan out your code. How would you like your game to play?
#
# Use a UML planner like:
#
#
# https://miro.com/
